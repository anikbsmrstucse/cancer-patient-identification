# %% [markdown]
# ## Import Liaberies

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## load Dataset

# %%
cancer_data = pd.read_csv('cancer-patient-data-sets.csv')

# %%
cancer_data.head(10)
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
# 5      5       P102   35       1              4            5             6
# 6      6       P103   52       2              2            4             5
# 7      7       P104   28       2              3            1             4
# 8      8       P105   35       2              4            5             6
# 9      9       P106   46       1              2            3             4
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# ...

# %%
print(cancer_data.columns)
# Out:
# Index(['index', 'Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %% [markdown]
# ## Remove Index and Paitent Id

# %%
data = cancer_data.drop(columns=['index', 'Patient Id'])

# %%
data.head(10)
# Out:
#    Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   33       1              2            4             5
# 1   17       1              3            1             5
# 2   35       1              4            5             6
# 3   37       1              7            7             7
# 4   46       1              6            8             7
# 5   35       1              4            5             6
# 6   52       2              2            4             5
# 7   28       2              3            1             4
# 8   35       2              4            5             6
# 9   46       1              2            3             4
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# ...

# %% [markdown]
# ## Find Null value

# %%
null_data = data.isnull().sum()
print("Missing values:\n", null_data)
# Out:
# Missing values:
#  Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %% [markdown]
# ## Target Columns Binarey Encoding

# %%
level_mapping = {
    'Low': 0,
    'Medium': 1,
    'High': 1
}

# %%
data['Level'] = data['Level'].replace(level_mapping)

# %%
data.head(10)
# Out:
#    Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   33       1              2            4             5
# 1   17       1              3            1             5
# 2   35       1              4            5             6
# 3   37       1              7            7             7
# 4   46       1              6            8             7
# 5   35       1              4            5             6
# 6   52       2              2            4             5
# 7   28       2              3            1             4
# 8   35       2              4            5             6
# 9   46       1              2            3             4
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# ...

# %% [markdown]
# ## Summarize the data set

# %%
#dimensions(no. of rows & columns)
print(data.shape)

#list of columns/features
print(data.columns)

#statistical summary
data.describe()
# Out:
# (1000, 24)
# Index(['Age', 'Gender', 'Air Pollution', 'Alcohol use', 'Dust Allergy',
#        'OccuPational Hazards', 'Genetic Risk', 'chronic Lung Disease',
#        'Balanced Diet', 'Obesity', 'Smoking', 'Passive Smoker', 'Chest Pain',
#        'Coughing of Blood', 'Fatigue', 'Weight Loss', 'Shortness of Breath',
#        'Wheezing', 'Swallowing Difficulty', 'Clubbing of Finger Nails',
#        'Frequent Cold', 'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')
#                Age       Gender  Air Pollution  Alcohol use  Dust Allergy  \
# count  1000.000000  1000.000000      1000.0000  1000.000000   1000.000000
# mean     37.174000     1.402000         3.8400     4.563000      5.165000
# std      12.005493     0.490547         2.0304     2.620477      1.980833
# min      14.000000     1.000000         1.0000     1.000000      1.000000
# 25%      27.750000     1.000000         2.0000     2.000000      4.000000
# ...

# %% [markdown]
# ## Specify the target variable and show its distribution

# %%
#target variable
target = data['Level']

#distribution of class labels or categories
print(pd.value_counts(target))

#alternative of finding class distribution
#print(iris_data.groupby('species').size())
# Out:
# 1    697
# 0    303
# Name: Level, dtype: int64

# %% [markdown]
# ## Spilt dataset into training and test data

# %%
seed = 7
train_data, test_data = train_test_split(data,test_size=0.3,random_state=seed, stratify=target)

#shape of the datasets
print('\nShape of training data :',train_data.shape)
print('\nShape of testing data : ',test_data.shape)

#class distribution of the training data
print(pd.value_counts(train_data['Level']))
#class distribution of the test data
print(pd.value_counts(test_data['Level']))
# Out:
# Shape of training data : (700, 24)
#
# Shape of testing data :  (300, 24)
# 1    488
# 0    212
# Name: Level, dtype: int64
# 1    209
# 0     91
# Name: Level, dtype: int64

# %% [markdown]
# ## Seperate the independent and target variable

# %%
#Seperate the independent and target variable from the training data
train_x = train_data.drop(columns=['Level'],axis=1)
train_y = train_data['Level']

#Seperate the independent and target variables from test data
test_x = test_data.drop(columns=['Level'],axis=1)
test_y = test_data['Level']

# %% [markdown]
# ## Show training data

# %%
train_x.head()
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 104   26       2              7            7             7
# 413   52       2              1            2             3
# 357   23       2              4            2             3
# 194   36       2              2            1             5
# 773   44       1              6            7             7
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 104                     7             7                     6              7
# 413                     4             2                     4              3
# 357                     4             2                     3              2
# 194                     3             2                     3              2
# 773                     7             7                     6              7
#
#      Obesity  ...  Coughing of Blood  Fatigue  Weight Loss  \
# 104        7  ...                  7        2            7
# ...

# %% [markdown]
# ## Show training labels

# %%
train_y.head()
# Out:
# 104    1
# 413    1
# 357    0
# 194    1
# 773    1
# Name: Level, dtype: int64

# %%
from sklearn import preprocessing
normalizer = preprocessing.Normalizer()
train_x = normalizer.fit_transform(train_x)
test_x = normalizer.transform(test_x)

# %%
train_x = preprocessing.scale(train_x)
test_x = preprocessing.scale(test_x)

# %% [markdown]
# ## Save Result

# %%
result = []

# %% [markdown]
# ## Model build with logistic regressions

# %%
#import logistics Regression
from sklearn.linear_model import LogisticRegression

#create classifier object/model
model1 = LogisticRegression()

#train the model with fit function
model1.fit(train_x,train_y)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Predictions with Logistic Regression

# %%
#make predictions on training data
predictions_train = model1.predict(train_x)
train_accuracy = accuracy_score(train_y,predictions_train)
print('Training Accuracy:',train_accuracy)

#make predictions on test data
predictions_test = model1.predict(test_x)
test_accuracy = accuracy_score(test_y,predictions_test)
print('Test Accuracy:', test_accuracy)

#append results
result.append(['Logistic Regression', train_accuracy, test_accuracy])
# Out:
# Training Accuracy: 0.9628571428571429
# Test Accuracy: 0.9866666666666667

# %% [markdown]
# ## Build Model with SVM

# %%
#import SVM
from sklearn.svm import SVC

#create classifier object/model
model2 = SVC()

#train the model with fit function
model2.fit(train_x,train_y)
# Out:
# SVC()

# %% [markdown]
# ## Prediction with SVM

# %%
#make predictions on training data
predictions_train = model2.predict(train_x)
train_accuracy = accuracy_score(train_y,predictions_train)
print('Training Accuracy:',train_accuracy)

#make predictions on test data
predictions_test = model2.predict(test_x)
test_accuracy = accuracy_score(test_y,predictions_test)
print('Test Accuracy:', test_accuracy)

#append results
result.append(['SVM', train_accuracy, test_accuracy])
# Out:
# Training Accuracy: 1.0
# Test Accuracy: 1.0

# %% [markdown]
# ## Build the Model(K-Nearest Neighbours)

# %%
#import logistics Regression
from sklearn.neighbors import KNeighborsClassifier

#create classifier object/model
model3 = KNeighborsClassifier(n_neighbors=3)

#train the model with fit function
model3.fit(train_x,train_y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ## Predictions with KNN

# %%
#make predictions on training data
predictions_train = model3.predict(train_x)
train_accuracy = accuracy_score(train_y,predictions_train)
print('Training Accuracy:',train_accuracy)

#make predictions on test data
predictions_test = model3.predict(test_x)
test_accuracy = accuracy_score(test_y,predictions_test)
print('Test Accuracy:', test_accuracy)

#append results
result.append(['KNN', train_accuracy, test_accuracy])
# Out:
# Training Accuracy: 1.0
# Test Accuracy: 1.0

# %% [markdown]
# ## compare model performances

# %%
results = pd.DataFrame (result, columns=['Model','Training Accuracy','Test Accuracy'])
results
# Out:
#                  Model  Training Accuracy  Test Accuracy
# 0  Logistic Regression           0.962857       0.986667
# 1                  SVM           1.000000       1.000000
# 2                  KNN           1.000000       1.000000

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score

# Calculate True Positives (TP) and False Positives (FP) for training data
confusion_matrix_train = confusion_matrix(train_y, predictions_train)
tp_train = confusion_matrix_train[1, 1]
fp_train = confusion_matrix_train[0, 1]

# Calculate True Positives (TP) and False Positives (FP) for test data
confusion_matrix_test = confusion_matrix(test_y, predictions_test)
tp_test = confusion_matrix_test[1, 1]
fp_test = confusion_matrix_test[0, 1]



# Print the results
print('Training TP:', tp_train)
print('Training FP:', fp_train)


print('Test TP:', tp_test)
print('Test FP:', fp_test)
# Out:
# Training TP: 488
# Training FP: 0
# Test TP: 209
# Test FP: 0

# %%
def convert_labels_to_binary(labels, positive_label):
    return [1 if label == positive_label else 0 for label in labels]

def calculate_metrics(predictions, ground_truth):
    tp = 0
    fp = 0
    fn = 0

    for pred, label in zip(predictions, ground_truth):
        if pred == 1 and label == 1:
            tp += 1
        elif pred == 1 and label == 0:
            fp += 1
        elif pred == 0 and label == 1:
            fn += 1

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0

    return tp, fp, precision, recall

# %%
# Example usage:
predictions = model2.predict(test_x)
ground_truth = test_y

tp, fp, precision, recall = calculate_metrics(predictions, ground_truth)

print("True Positives (TP):", tp)
print("False Positives (FP):", fp)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# True Positives (TP): 209
# False Positives (FP): 0
# Precision: 1.0
# Recall: 1.0

# %%
# Example usage:
predictions = model1.predict(test_x)
ground_truth = test_y

tp, fp, precision, recall = calculate_metrics(predictions, ground_truth)

print("True Positives (TP):", tp)
print("False Positives (FP):", fp)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# True Positives (TP): 208
# False Positives (FP): 3
# Precision: 0.985781990521327
# Recall: 0.9952153110047847

# %%
# Example usage:
predictions = model3.predict(test_x)
ground_truth = test_y

tp, fp, precision, recall = calculate_metrics(predictions, ground_truth)

print("True Positives (TP):", tp)
print("False Positives (FP):", fp)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# True Positives (TP): 209
# False Positives (FP): 0
# Precision: 1.0
# Recall: 1.0
